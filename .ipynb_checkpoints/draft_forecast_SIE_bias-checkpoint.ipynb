# %%
import xarray as xr
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from datetime import datetime, timedelta
# Out:
# /home/disk/sipn/mcmcgraw/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/disk/sipn/mcmcgraw/anaconda3/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
model_name = 'ecmwfsipn'
model_type = 'forecast'
no_day_change = 5


filepath_save = '/home/disk/sipn/mcmcgraw/data/VRILE/'
filename_full = filepath_save+'{model_name}_{model_type}_2018_TEST_SIE_d_SIE_{d_days}day_change_lead_time_ALL_REGIONS_ALL_ENS.csv'.format(model_name=model_name,
                       model_type=model_type,d_days=no_day_change)
d_SIE = pd.read_csv(filename_full)
d_SIE_all = d_SIE.dropna()

# %%
regions = d_SIE_all['region'].unique().tolist() #list unique regions
lead_days = d_SIE_all['lead time (days)'].unique().tolist()

# %%
region_choose = 'panArctic'
SIE_region_groups = d_SIE_all.groupby(['region'])
SIE_region_sel = SIE_region_groups.get_group(region_choose)
SIE_region_sel.head()
# Out:
#        Unnamed: 0 I (init date)       V (valid date)  \
# 32895           0    2018-01-01  2018-01-03 00:00:00
# 32896           0    2018-01-01  2018-01-04 00:00:00
# 32897           0    2018-01-01  2018-01-05 00:00:00
# 32898           0    2018-01-01  2018-01-06 00:00:00
# 32899           0    2018-01-01  2018-01-07 00:00:00
#
#        V_mon (valid date month)  V_yr (valid date year)        SIE  \
# 32895                       1.0                  2018.0  12.006032
# 32896                       1.0                  2018.0  12.068311
# 32897                       1.0                  2018.0  12.097761
# 32898                       1.0                  2018.0  12.126469
# 32899                       1.0                  2018.0  12.118109
#
#        lead time (days)  d_SIC (V - I)  ensemble     region
# 32895               2.0       0.248876       1.0  panArctic
# 32896               3.0       0.202007       1.0  panArctic
# 32897               4.0       0.112077       1.0  panArctic
# 32898               5.0       0.106824       1.0  panArctic
# 32899               6.0       0.144775       1.0  panArctic

# %%
SIE_lead_groups = SIE_region_sel.groupby(['lead time (days)'])
SIE_lead_sel = SIE_lead_groups.get_group(2)
SIE_model_dates = pd.to_datetime(SIE_lead_sel['V (valid date)'])

# %% [markdown]
# OBS

# %%
obs_name = 'NSIDC_0079'
obs_type = 'sipn_nc_yearly_agg'
obs_filename = '/home/disk/sipn/mcmcgraw/data/VRILE/{model_name}_{model_type}_SIE_d_SIE_{d_days}day_change_lead_time_ALL_REGIONS_ALL_ENS.csv'.format(model_name=obs_name,
                       model_type=obs_type,d_days=no_day_change)
SIE_obs = pd.read_csv(obs_filename)
SIE_obs = SIE_obs.dropna()
SIE_obs.head()
# Out:
#    Unnamed: 0 V (valid date)  V_mon (valid date month)        SIE  \
# 0           0     1989-01-03                       1.0  14.585865
# 1           1     1989-01-04                       1.0  14.595622
# 2           2     1989-01-05                       1.0  14.586416
# 3           3     1989-01-06                       1.0  14.622716
# 4           4     1989-01-07                       1.0  14.659128
#
#    d_SIC (V - I) ensemble     region
# 0       0.130135      obs  panArctic
# 1       0.118162      obs  panArctic
# 2       0.073263      obs  panArctic
# 3       0.114523      obs  panArctic
# 4       0.239570      obs  panArctic

# %%
SIE_obs_dates = pd.to_datetime(SIE_obs['V (valid date)'])
SIE_model_day = SIE_model_dates.dt.day
SIE_obs_match_dates = SIE_obs.loc[pd.to_datetime(SIE_obs['V (valid date)']).dt.day==3]
SIE_obs_reg_group = SIE_obs_match_dates.groupby(['region'])
SIE_obs_reg_sel = SIE_obs_reg_group.get_group(region_choose)
SIE_obs_reg_sel.head()
# Out:
#      Unnamed: 0 V (valid date)  V_mon (valid date month)        SIE  \
# 0             0     1989-01-03                       1.0  14.585865
# 31           31     1989-02-03                       2.0  15.688681
# 59           59     1989-03-03                       3.0  15.911278
# 90           90     1989-04-03                       4.0  15.272040
# 120         120     1989-05-03                       5.0  13.426917
#
#      d_SIC (V - I) ensemble     region
# 0         0.130135      obs  panArctic
# 31       -0.050604      obs  panArctic
# 59        0.088639      obs  panArctic
# 90       -0.068591      obs  panArctic
# 120      -0.158501      obs  panArctic

# %%
yr_sel = 2018
SIE_yr_sel = SIE_obs_reg_sel.loc[pd.to_datetime(SIE_obs_reg_sel['V (valid date)']).dt.year==yr_sel]
# Out:
#        Unnamed: 0 V (valid date)  V_mon (valid date month)        SIE  \
# 10592       10592     2018-01-03                       1.0  12.914594
# 10623       10623     2018-02-03                       2.0  13.948313
# 10651       10651     2018-03-03                       3.0  14.256116
# 10682       10682     2018-04-03                       4.0  14.049961
# 10712       10712     2018-05-03                       5.0  13.071696
# 10743       10743     2018-06-03                       6.0  11.517952
# 10773       10773     2018-07-03                       7.0   9.983620
# 10804       10804     2018-08-03                       8.0   6.863255
# 10835       10835     2018-09-03                       9.0   5.133417
# 10865       10865     2018-10-03                      10.0   5.082369
# 10896       10896     2018-11-03                      11.0   8.915199
# 10926       10926     2018-12-03                      12.0  11.188662
#
#        d_SIC (V - I) ensemble     region
# 10592       0.163256      obs  panArctic
# 10623       0.043761      obs  panArctic
# 10651      -0.101254      obs  panArctic
# 10682      -0.078848      obs  panArctic
# 10712      -0.304554      obs  panArctic
# 10743      -0.223597      obs  panArctic
# 10773      -0.255779      obs  panArctic
# 10804      -0.270408      obs  panArctic
# 10835      -0.070625      obs  panArctic
# 10865       0.129995      obs  panArctic
# 10896       0.483439      obs  panArctic
# 10926       0.080866      obs  panArctic

# %%
import seaborn as sns
fig1 = plt.figure(1)
ax1=sns.boxplot(x='V (valid date)',y='SIE',data=SIE_lead_sel)
ax1.set_xlabel('Month',fontsize=13)
ax1.set_ylabel('Sea Ice Extent ($10^6 km^2$)',fontsize=13)
ax1.set_xticklabels(['J','F','M','A','M','J','J','A','S','O','N','D'])
#ax1.set_title('{yr_choose} {title_var}, {region} ({model_name} {model_type}), lead days: {lead_day}'.format(yr_choose=yr_sel,title_var=titlename_choose_var,
#              region=region_sel,
#              model_name=model_name,model_type=model_type,lead_day=lead_ind_sel),fontsize=14)
ax1.plot(np.arange(0,12),SIE_yr_sel['SIE'])

# %%
SIE_dates = SIE_lead_sel.groupby('V (valid date)').mean()
bias_2018 = SIE_dates['SIE'].values - SIE_yr_sel['SIE'].values
SIE_obs_dates = SIE_obs_reg_sel.groupby(pd.to_datetime(SIE_obs_reg_sel['V (valid date)']).dt.day).mean()
bias_obs_all = SIE_dates['SIE'].values - SIE_obs_dates['SIE'].values

# %%
SIE_obs_dates = SIE_obs_reg_sel.groupby(pd.to_datetime(SIE_obs_reg_sel['V (valid date)']).dt.day).mean()
